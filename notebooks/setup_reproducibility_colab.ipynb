# %% [markdown]
# # Luhya ASR - Setup and Installation
#
# ## Quick Start Guide for Reproducibility
#
# This notebook provides a step-by-step guide to clone the repository, install dependencies, and prepare the environment for training the Luhya Automatic Speech Recognition model.

# %% [markdown]
# ## 1. Mount Google Drive

# %%
from google.colab import drive
drive.mount('/content/drive')

# %% [markdown]
# ## 2. Clone the Repository

# %%
# Clone the repository from GitHub
# !git clone https://github.com/Romusthagore/luhya-asr_w2v-bert.git

# Navigate to the project directory
# %cd luhya-asr_w2v-bert

# Display the project structure
# !ls -la

# %% [markdown]
# ## 3. Install Dependencies

# %%
# Install all required packages
# !pip install -r requirements.txt

# Verify the installation
# !python -c "import torch, transformers, datasets, evaluate; print('All imports successful')"

# %% [markdown]
# ## 4. Add Project to Python Path

# %%
import sys
sys.path.append('/content/luhya-asr_w2v-bert')

print("Project added to Python path")
print(f"Path: {sys.path[-1]}")

# %% [markdown]
# ## 5. Verify the Setup

# %%
# Test module imports
from src.utils.config import ASRConfig
from src.data.dataset import load_datasets
from src.training.trainer import create_asr_trainer

print("All modules imported successfully")
print("\nProject Structure:")
# !ls -la src/

# %%
# Check GPU availability
import torch

print(f"Python version: {sys.version}")
print(f"PyTorch version: {torch.__version__}")
print(f"GPU available: {torch.cuda.is_available()}")
if torch.cuda.is_available():
    print(f"GPU: {torch.cuda.get_device_name(0)}")
    print(f"Memory: {torch.cuda.get_device_properties(0).total_memory / 1024**3:.1f} GB")

# %% [markdown]
# ## 6. Ready to Train

# %%
print("="*60)
print("SETUP COMPLETED SUCCESSFULLY")
print("="*60)
print("\nTo start training, run:")
print("python3 scripts/train_model.py --config configs/train_config_colab.yaml")
print("\nTo use the training notebook:")
print("Open notebooks/train_w2v-bert.ipynb")
print("\nResults will be saved to:")
print("/content/drive/MyDrive/luhya-asr-output/")
